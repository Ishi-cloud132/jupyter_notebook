# %%
import os 
print (os.getcwd())
# Out:
# C:\Users\ishig\anaconda_projects

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'anaconda3', 'climate.txt', 'csvfile.ipynb', 'data', 'db', 'demo1.ipynb', 'fifa.csv', 'first', 'gasprice.png', 'gas_prices.csv', 'healthcare_dataset.csv', 'Housing.csv', 'housing.ipynb', 'housing_prices.csv', 'matplot.ipynb', 'metaplotlib.ipynb', 'mygraph.png', 'numpy.ipynb', 'os.ipynb', 'panda.ipynb', 'results.txt', 'student_details.csv', 'test.csv', 'train.csv', 'Untitled.ipynb', 'Untitled1.ipynb', 'Untitled2.ipynb', 'Untitled3.ipynb', 'Untitled4.ipynb', 'Untitled5.ipynb']

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

val=pd.read_csv("C:\\Users\\ishig\\anaconda_projects\\Housing.csv")
val
val.describe()
val=pd.read_csv("C:\\Users\\ishig\\anaconda_projects\\Housing.csv")
val
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

val=pd.read_csv("C:\\Users\\ishig\\anaconda_projects\\Housing.csv")
val
val.describe()
val=pd.read_csv("C:\\Users\\ishig\\anaconda_projects\\Housing.csv")
val

from sklearn.linear_model import LinearRegression
model=LinearRegression()
features = ['mainroad', 'guestroom', 'basement', 'airconditioning']
import numpy as np
for feature in features:
    val[feature] = np.where(val[feature] == 'yes', 1, 0)
x = val[['area', 'bedrooms', 'bathrooms', 'stories', 'parking', 'mainroad', 'guestroom', 'basement', 'airconditioning']]
y = val['price'] 
model.fit(x, y)
   # model.predict(np .array([[7800,2,2,1,1,0,1,0,1]])
    
# sample_input = pd.DataFrame([[7800, 2, 2, 1, 1, 0, 1, 1, 1]])
val['predicted_price'] = model.predict(x)


print(val.head(10))

plt.figure(figsize=(8, 6))
sns.lineplot(x=val['price'], y=val['predicted_price'])
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual vs Predicted Housing Prices")
plt.show()

from sklearn.metrics import mean_squared_error
loss=np.sqrt(mean_squared_error(val['price'],val['predicted_price']))
loss
# Out:
#       price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0  13300000   7420         4          2        3         1          0
# 1  12250000   8960         4          4        4         1          0
# 2  12250000   9960         3          2        2         1          0
# 3  12215000   7500         4          2        2         1          0
# 4  11410000   7420         4          1        2         1          1
# 5  10850000   7500         3          3        1         1          0
# 6  10150000   8580         4          3        4         1          0
# 7  10150000  16200         5          3        2         1          0
# 8   9870000   8100         4          1        2         1          1
# 9   9800000   5750         3          2        4         1          1
#
#    basement hotwaterheating  airconditioning  parking prefarea  \
# 0         0              no                1        2      yes
# 1         0              no                1        3       no
# ...

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
val=pd.read_csv("C:\\Users\\ishig\\anaconda_projects\\Housing.csv")
features = ['mainroad', 'guestroom', 'basement', 'airconditioning']
import numpy as np
for feature in features:
    val[feature] = np.where(val[feature] == 'yes', 1, 0)

from sklearn.linear_model import LinearRegression
model=LinearRegression()
inputs, targets = val[['area', 'bedrooms', 'bathrooms', 'stories', 'parking', 'mainroad', 'guestroom', 'basement', 'airconditioning']],val['price']
model.fit(inputs,targets)
val['predictions']=model.predict(inputs)
print( val[['predictions','price']].head(10))
sns.scatterplot(x=val['price'],y=val['predictions'])
from sklearn.metrics import mean_squared_error
loss=np.sqrt(mean_squared_error(val['price'],val['predictions']))
loss
# Out:
#     predictions     price
# 0  7.642485e+06  13300000
# 1  1.087642e+07  12250000
# 2  7.371872e+06  12250000
# 3  8.003394e+06  12215000
# 4  7.002487e+06  11410000
# 5  8.087579e+06  10850000
# 6  9.446571e+06  10150000
# 7  9.224382e+06  10150000
# 8  7.185559e+06   9870000
# 9  7.562719e+06   9800000
# 1112669.8942322636

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
val=pd.read_csv("C:\\Users\\ishig\\anaconda_projects\\Housing.csv")

from sklearn.linear_model import LinearRegression
model=LinearRegression()
from sklearn.preprocessing import StandardScaler 
features = ['mainroad', 'guestroom', 'basement', 'airconditioning']
import numpy as np
for feature in features:
    val[feature] = np.where(val[feature] == 'yes', 1, 0)
x = val[['area', 'bedrooms', 'bathrooms', 'stories', 'parking', 'mainroad', 'guestroom', 'basement', 'airconditioning']]
y = val['price'] 
scaler=StandardScaler()
scaler.fit(x)
scaler.mean_
scaled_input=scaler.transform(x)
scaled_input
# Out:
# array([[ 1.04672629,  1.40341936,  1.42181174, ..., -0.46531479,
#         -0.73453933,  1.4726183 ],
#        [ 1.75700953,  1.40341936,  5.40580863, ..., -0.46531479,
#         -0.73453933,  1.4726183 ],
#        [ 2.21823241,  0.04727831,  1.42181174, ..., -0.46531479,
#          1.3613975 , -0.67906259],
#        ...,
#        [-0.70592066, -1.30886273, -0.57018671, ..., -0.46531479,
#         -0.73453933, -0.67906259],
#        [-1.03338891,  0.04727831, -0.57018671, ..., -0.46531479,
#         -0.73453933, -0.67906259],
#        [-0.5998394 ,  0.04727831, -0.57018671, ..., -0.46531479,
#         -0.73453933, -0.67906259]])

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
val=pd.read_csv("C:\\Users\\ishig\\anaconda_projects\\Housing.csv")
features = ['mainroad', 'guestroom', 'basement', 'airconditioning']
import numpy as np
for feature in features:
    val[feature] = np.where(val[feature] == 'yes', 1, 0)
    x = val[['area', 'bedrooms', 'bathrooms', 'stories', 'parking', 'mainroad', 'guestroom', 'basement', 'airconditioning']]
y = val['price'] 

from sklearn.model_selection import train_test_split  
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
x_test['prediction']=model.predict(x_test)
x_test.head(10)
plt.scatter(y_test,prediction)

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
val=pd.read_csv("C:\\Users\\ishig\\anaconda_projects\\Housing.csv")
features = ['mainroad', 'guestroom', 'basement', 'airconditioning']
import numpy as np
for feature in features:
    val[feature] = np.where(val[feature] == 'yes', 1, 0)
x = val[['area', 'bedrooms', 'bathrooms', 'stories', 'parking', 'mainroad', 'guestroom', 'basement', 'airconditioning']]
y = val['price'] 

from sklearn.model_selection import train_test_split  
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)
from sklearn import linear_model
lasso_reg=linear_model.Lasso(alpha=50,max_iter=100,tol=0.1)
lasso_reg.fit(x_train,y_train)
lasso_reg.score(x_test,y_test)
# Out:
# 0.7346382331853937

# %%
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
val=pd.read_csv("C:\\Users\\ishig\\anaconda_projects\\Housing.csv")
sns.barplot(data=val,x='airconditioning',y='price');

# %%
air_code={'yes':1,'no':0}
val['air_code']=val.airconditioning.map(air_code)
val
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
val.price.corr(val.air_code)
# Out:
# 0.45295408425604816

# %%
colors = ['#FF5733', '#33FF57', '#3357FF']
sns.barplot(data=val,x='furnishingstatus',y='price',palette=colors)
# Out:
# C:\Users\ishig\AppData\Local\Temp\ipykernel_12540\3620170457.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=val,x='furnishingstatus',y='price',palette=colors)
# <Axes: xlabel='furnishingstatus', ylabel='price'>

# %%
fur_map = {'furnished': 2, 'semi-furnished': 1, 'unfurnished': 0}
val['furnishingstatus'] = val['furnishingstatus'].map(fur_map)
val
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
from sklearn import preprocessing 
enc=preprocessing.OneHotEncoder()
enc.fit(val[['furnishingstatus']])
enc.categories_
one_hot=enc.transform(val[['furnishingstatus']]).toarray()
one_hot
val[['furnished','semi-furnished','unfurnished']]=one_hot
val
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
from sklearn.preprocessing import StandardScaler
feature= ['area','bedrooms','bathrooms']
scaler=StandardScaler()
scaler.fit(val[feature])
# Out:
# StandardScaler()
