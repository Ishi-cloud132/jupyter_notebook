# %%
#writing csv file
import pandas as pd
dis={'a':[1,2,3,4,5,6],
's':[1,2,3,4,5,6],
'd':[1,2,3,4,5,6]
}
    
d=pd.DataFrame(dis,index=['a','b','c','d','e','f'])
print(d)
d.to_csv("test.csv",header=[1,2,3])
#read csv
csv_1=pd.read_csv("C:\\Users\\ishig\\anaconda_projects\\housing_prices.csv")
print(csv_1)
csv_2=pd.read_csv("C:\\Users\\ishig\\anaconda_projects\\housing_prices.csv",nrows=5)
print(csv_2)
print(type(csv_2))
csv_3=pd.read_csv("C:\\Users\\ishig\\anaconda_projects\\housing_prices.csv",usecols=["House_ID","Location"])
print(csv_3)
csv_4=pd.read_csv("C:\\Users\\ishig\\anaconda_projects\\housing_prices.csv",skiprows=[0,1,2,4,5,])
print(csv_4)
csv_5=pd.read_csv("C:\\Users\\ishig\\anaconda_projects\\housing_prices.csv",index_col="Location")

print(csv_5)
csv_5=pd.read_csv("C:\\Users\\ishig\\anaconda_projects\\housing_prices.csv",header=2)

print(csv_5)
csv_6=pd.read_csv("C:\\Users\\ishig\\anaconda_projects\\housing_prices.csv",names=['col1','col2','col3','col4','col5'])

print(csv_6)
csv_7=pd.read_csv("C:\\Users\\ishig\\anaconda_projects\\housing_prices.csv",dtype={"Price_in_USD":"float"})

print(csv_7)
csv_8=pd.read_csv("C:\\Users\\ishig\\anaconda_projects\\housing_prices.csv" , usecols["Year_Built"])
print(csv_8)
# Out:
#    a  s  d
# a  1  1  1
# b  2  2  2
# c  3  3  3
# d  4  4  4
# e  5  5  5
# f  6  6  6
#     House_ID Location  Size_in_sq_ft  Price_in_USD  Year_Built
# 0          1    Rural           2827        494070        1974
# 1          2    Urban           3495        452228        1967
# 2          3    Rural           2295        531839        2015
# 3          4    Rural           1962        369536        2003
# 4          5    Urban           2322        417824        1984
# ..       ...      ...            ...           ...         ...
# 95        96    Urban           2960        601157        1974
# 96        97    Urban            801        284423        2007
# 97        98    Rural           1441        616349        2012
# 98        99    Urban           3067        803714        2011
# 99       100    Urban           2389        757917        1971
#
# [100 rows x 5 columns]
#    House_ID Location  Size_in_sq_ft  Price_in_USD  Year_Built
# ...

# %%
import pandas as pd
df = pd.read_csv('C:\\Users\\ishig\\anaconda_projects\\Housing.csv')
df
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import LeaveOneOut
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, precision_score, f1_score, roc_auc_score, confusion_matrix, roc_curve
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler

# Load your dataset (assuming you have a dataset like Titanic, or similar)
# Example: df = pd.read_csv('path_to_your_dataset.csv')

# Load dataset
df = pd.read_csv('C:\\Users\\ishig\\anaconda_projects\\train.csv')

# Split your dataset into features and target
x = df.drop('Survived', axis=1)  # Features
y = df['Survived']  # Target

# Preprocessing: Handle missing values if necessary (e.g., fill missing values)
# Make sure you're only filling missing values in numeric columns
x = x.select_dtypes(include=['float64', 'int64']).fillna(x.mean())  # Fill only numeric columns

# Optional: Convert categorical variables to numerical (if any)
x = pd.get_dummies(x, drop_first=True)  # This converts categorical variables

# Scaling features (important for SVM)
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)

# Use a smaller subset for debugging (e.g., first 100 rows)
x_small = x_scaled[:100]  # First 100 rows of x_scaled
y_small = y[:100]  # First 100 rows of y

# Initialize LeaveOneOut
print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 21
#      17 y = df['Survived']  # Target
#      19 # Preprocessing: Handle missing values if necessary (e.g., fill missing values)
#      20 # Make sure you're only filling missing values in numeric columns
# ---> 21 x = x.select_dtypes(include=['float64', 'int64']).fillna(x.mean())  # Fill only numeric columns
#      23 # Optional: Convert categorical variables to numerical (if any)
#      24 x = pd.get_dummies(x, drop_first=True)  # This converts categorical variables
#
# File ~\anaconda\Lib\site-packages\pandas\core\frame.py:11693, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11685 @doc(make_doc("mean", ndim=2))
#   11686 def mean(
#   11687     self,
#    (...)
#   11691     **kwargs,
#   11692 ):
# > 11693     result = super().mean(axis, skipna, numeric_only, **kwargs)
# ...
